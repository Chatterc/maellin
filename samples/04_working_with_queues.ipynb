# %%
import os
import time
import asyncio

os.chdir(path='./../')

from maellin.tasks import Task
from maellin.queues import QueueFactory

# %% [markdown]
# ### Lets Make some Dummy Functions to use as Tasks

# %%
def foo():
    print('I am foo and I am being worked on...')
    time.sleep(0.1)
    
def bar():
    print('I am bar and I am being worked on...')
    time.sleep(0.1)

# %% [markdown]
# ### Lets define a basic worker function to grab and process Tasks from the Queue

# %%
def worker(queue):

    while not queue.empty():
        start_time = time.time()
        _tsk = queue.get()
        print(f'Worker pulled \'{_tsk.func.__name__}\' from the Queue...')
        
        print('Running Task...')
        _tsk.run()
        
        queue.task_done()
        print('Task Completed in %2f seconds' % (time.time() - start_time))

# %% [markdown]
# ### Next lets create some tasks, instantiate our Queue, and use a worker to process tasks from the Queue

# %%
def main():
    start_time = time.time()
    # Instantiate some Tasks for use to enqueue
    tsk_1 = Task(foo)
    tsk_2 = Task(bar)
    
    # Instantiate a queue using our Queue Factory 
    q = QueueFactory.factory('default')
    
    # Enqueue Tasks by putting them in the queue
    q.put(tsk_1)
    q.put(tsk_2)
    print("Total Tasks in the Queue %i" % q.qsize())

    # Give the queue to a worker that can process tasks
    worker(q)
    print('Synchronous Pipeline Processed in %2f seconds' % (time.time() - start_time))
    
if __name__ == '__main__':
    main()
# Out:
# Total Tasks in the Queue 2
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.114009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111007 seconds
# Synchronous Pipeline Processed in 0.226018 seconds

# %% [markdown]
# # AsyncIO Example
# Now lets look at a simplle `main.py` file that demonstrates how to uses asynchronous task processing
# Because `Jupyter Notebooks` Run an event loop, it creates conflicts with asyncio without nesting a new event loop.
# DO NOT NEST EVENT LOOPS

# %%
def main():
    start_time = time.time()
    # Instantiate some Tasks for use to enqueue
    tsk_1 = Task(foo)
    tsk_2 = Task(bar)
    
    # Instantiate a queue using our Queue Factory 
    q = QueueFactory.factory('default')
    
    # Enqueue Tasks by putting them in the queue
    for i in range(100):
        q.put(tsk_1)
        q.put(tsk_2)
    print("Total Tasks in the Queue %i" % q.qsize())

    # Give the queue to a worker that can process tasks
    worker(q)
    print('Synchronous Pipeline Processed in %2f seconds' % (time.time() - start_time))
    
if __name__ == '__main__':
    main()
# Out:
# Total Tasks in the Queue 200
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.106010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111005 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110011 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110005 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.107005 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107014 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108005 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108011 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.105008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110016 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110001 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109995 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110000 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108004 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107011 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110004 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.107006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.106009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110004 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109004 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109011 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111005 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112011 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112005 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109012 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112005 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108003 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.107987 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111021 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107998 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109011 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111002 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110003 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109011 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111012 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110026 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111993 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110005 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108001 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112015 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107004 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.105004 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110004 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112011 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107004 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111011 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.106005 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108009 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108005 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.113011 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.105007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110996 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.112010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.107006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109004 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.107008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108012 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.108006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107001 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111005 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108005 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109012 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.107006 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107005 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.107009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110006 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.107007 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110999 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.107008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110010 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109013 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.107001 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110010 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110011 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.109003 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111011 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.110009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108005 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.111009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.108007 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.109009 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.111008 seconds
# Worker pulled 'foo' from the Queue...
# Running Task...
# I am foo and I am being worked on...
# Task Completed in 0.112008 seconds
# Worker pulled 'bar' from the Queue...
# Running Task...
# I am bar and I am being worked on...
# Task Completed in 0.110008 seconds
# Synchronous Pipeline Processed in 21.947638 seconds
